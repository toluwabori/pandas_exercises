# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %% [markdown]
# ### Introduction:
#
# This time you will create a data
#
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.

# %% [markdown]
# ### Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Assign it to a variable called crime.

# %%
import pandas as pd
df_crime = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv')
df_crime
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 0   1960   179323175   3384200   288460   3095700    9110          17190
# 1   1961   182992000   3488000   289390   3198600    8740          17220
# 2   1962   185771000   3752200   301510   3450700    8530          17550
# 3   1963   188483000   4109500   316970   3792500    8640          17650
# 4   1964   191141000   4564600   364220   4200400    9360          21420
# 5   1965   193526000   4739400   387390   4352000    9960          23410
# 6   1966   195576000   5223500   430180   4793300   11040          25820
# 7   1967   197457000   5903400   499930   5403500   12240          27620
# 8   1968   199399000   6720200   595010   6125200   13800          31670
# 9   1969   201385000   7410900   661870   6749000   14760          37170
# 10  1970   203235298   8098000   738820   7359200   16000          37990
# 11  1971   206212000   8588200   816500   7771700   17780          42260
# ...

# %% [markdown]
# ### What is the type of the columns?

# %%
df_crime.dtypes
# Out:
# Year                  int64
# Population            int64
# Total                 int64
# Violent               int64
# Property              int64
# Murder                int64
# Forcible_Rape         int64
# Robbery               int64
# Aggravated_assault    int64
# Burglary              int64
# Larceny_Theft         int64
# Vehicle_Theft         int64
# dtype: object

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Convert the type of the column Year to datetime64

# %%
df_crime.Year= pd.to_datetime(df_address.Year,format='%Y')

# %% [markdown]
# ### Set the Year column as the index of the dataframe

# %%
df_crime.set_index('Year')
# Out:
#             Population     Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175   3384200   288460   3095700    9110          17190
# 1961-01-01   182992000   3488000   289390   3198600    8740          17220
# 1962-01-01   185771000   3752200   301510   3450700    8530          17550
# 1963-01-01   188483000   4109500   316970   3792500    8640          17650
# 1964-01-01   191141000   4564600   364220   4200400    9360          21420
# 1965-01-01   193526000   4739400   387390   4352000    9960          23410
# 1966-01-01   195576000   5223500   430180   4793300   11040          25820
# 1967-01-01   197457000   5903400   499930   5403500   12240          27620
# 1968-01-01   199399000   6720200   595010   6125200   13800          31670
# 1969-01-01   201385000   7410900   661870   6749000   14760          37170
# 1970-01-01   203235298   8098000   738820   7359200   16000          37990
# ...

# %% [markdown]
# In which year did we have the most crime commited , considering the last 10 years.

# %%
import seaborn as sns 
sns.barplot(x=df_crime.Murder, y=df_crime.Year.nlargest(10));

# %% [markdown]
# ### Delete the Total column

# %% [markdown]
# ### Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
df_crime.resample('10AS').sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 df_crime.resample('10AS').sum()
#
# File /Applications/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:10550, in DataFrame.resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level, origin, offset)
#   10534 @doc(NDFrame.resample, **_shared_doc_kwargs)
#   10535 def resample(
#   10536     self,
#    (...)
#   10548     offset: TimedeltaConvertibleTypes | None = None,
#   10549 ) -> Resampler:
# > 10550     return super().resample(
#   10551         rule=rule,
#   10552         axis=axis,
#   10553         closed=closed,
#   10554         label=label,
#   10555         convention=convention,
#   10556         kind=kind,
#   10557         loffset=loffset,
#   10558         base=base,
#   10559         on=on,
#   10560         level=level,
# ...

# %% [markdown]
# ### What is the most dangerous decade to live in the US?
